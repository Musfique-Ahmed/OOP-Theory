# %%
class Point:
    def __init__(self, xCor = 0, yCor=0):
        self.x = xCor
        self.y = yCor
    def show(self):
        print(f"({self.x},{self.y})")   
    def increaseX(self,val):
        self.x+=val
    def increaseY(self,val):
        self.y+=val
p1 = Point(50,50)
p1.show()

p1.increaseX(5)
p1.increaseY(-5)
p1.show()
# Out:
# (50,50)
# (55,45)

# %%
class Rectangle:
    def __init__(self,w,h):
        self.width=w
        self.height=h
    def getArea(self):
        return self.height*self.width
r = Rectangle(4,12)
print(r.getArea())
# Out:
# 48

# %%
class Point:
    def __init__(self, xCor = 0, yCor=0):
        self.x = xCor
        self.y = yCor
    def show(self):
        print(f"({self.x},{self.y})")
def change(q):
    q.x=15
    q.show()
p = Point()
p.show()
change(p)
p.show()
# Out:
# (0,0)
# (15,0)
# (15,0)

# %%
class Point:
    def __init__(self, xCor = 0, yCor=0):
        self.x = xCor
        self.y = yCor
    def show(self):
        print(f"({self.x},{self.y})")
class Line:
    def __init__(self,p1,p2):
        self.start = p1
        self.end = p2
    def show(self):
        print("Start:",end="")
        self.start.show()
        print("End:",end="")
        self.end.show()
l= Line(Point(0,0),Point(4,5))
l.show()
# Out:
# Start:(0,0)
# End:(4,5)

# %%
class Student:
    university = "UIU"

    def __init__(self, name):
        self.name = name

    @classmethod #Decoratior
    def change_university(cls, new_university):   # class method
        cls.university = new_university

s1 = Student("Musfique")
s2 = Student("Tasfiya")
Student.change_university("DU")
# s1.show()
print(s1.university)     # UIU
print(Student.university) # DU
print(s2.university)     # DU
# Out:
# DU
# DU
# DU

# %%
class Point:
    def __init__(self, x, y):
        self.x = x
        self.y = y

 # Official representation (for developers/debugging)
    def __repr__(self):
        return f"Point(x={self.x}, y={self.y})"

 # User-friendly representation (for end-users)
    def __str__(self):
        return f"({self.x}, {self.y})"

p = Point(10, 20)

 #  print() and str() call __str__()
print(p) # Output: (10, 20)
print(str(p)) # Output: (10, 20)

# 2. Interactive console and repr() call __repr__()
print(repr(p)) # Output: Point(x=10, y=20)
# Out:
# (10, 20)
# (10, 20)
# Point(x=10, y=20)

# %%
class Account:
    def __init__(self, initial_balance = 500):
# "Private" attribute (name mangling)
        self.__balance = initial_balance
# "Protected" attribute (convention)
        self._owner_name = "Anonymous"
# Public method to access the balance
    def get_balance(self):
        return self.__balance

    # "Private" method (name mangling)
    def __update_balance(self, amount):
        self.__balance += amount
        print("Balance updated internally.")

    def deposit(self, amount):
        if amount > 0:
            # We call the private method internally
            self.__update_balance(amount)

acc = Account(500)
acc.deposit(100)
print(f"Current Balance: {acc.get_balance()}")

# acc.__update_balance(200)  # This will raise an AttributeError

# External attempts (Discouraged/Failed/Difficult)
print(f"Owner Name (Access discouraged): {acc._owner_name}")

# Accessing mangled attribute (Technically possible, but bad practice)
# print(f"Mangled Balance: {acc._Account__balance}")
# Out:
# Balance updated internally.
# Current Balance: 600
# Owner Name (Access discouraged): Anonymous

# %%
class Course:
    def __init__(self, course_name, credits):
        self.course_name = course_name
        self.credits = credits

    def display_info(self):
        print(f"Course Name: {self.course_name}, Credits: {self.credits}")


bangla = Course("Bangla", 3)
bangla.display_info()

english = Course("English", 3)
english.display_info()
# Out:
# Course Name: Bangla, Credits: 3
# Course Name: English, Credits: 3

# %%
class Time:
    def __init__(self,h=0,m=0):
        self.hour = h
        self.min=m
    def __add__(self,other):
        return Time(self.hour+other.hour,self.min+other.min)
    def __str__(self):
        return f"{self.hour} hours {self.min} mins"
t1 = Time(10,30)
t2 = Time(5,10)
print(t1+t2)
# Out:
# 15 hours 40 mins

# %%
class Sword:
   def __init__(self, name, weight):
       self.name = name
       self.weight = weight
   def __add__(self, other):
       combined_name = self.name + '-' + other.name
       combined_weight = self.weight + other.weight
       return Sword(combined_name, combined_weight)
   def __gt__(self, other):
       return self.weight > other.weight
   def __str__(self):
       return f"{self.name} (Weight: {self.weight} kg)"
sword1 = Sword("Dragon Fang", 3.5)
sword2 = Sword("Phoenix Claw", 4.2)
legendary_sword = Sword("Excalibur", 8.0)
fusion_sword = sword1 + sword2
print(f"Combined Sword: {fusion_sword}")
if fusion_sword > legendary_sword:
   print(f"{fusion_sword.name} is heavier than {legendary_sword.name}.")
else:
   print(f"{fusion_sword.name} is lighter than {legendary_sword.name}.")
# Out:
# Combined Sword: Dragon Fang-Phoenix Claw (Weight: 7.7 kg)
# Dragon Fang-Phoenix Claw is lighter than Excalibur.

# %%
class A:
    pass
a = A()
a.name = "UIU"
print(a.name)
b = a
print(b.name)
b.name = "United International University"
print(a.name)
print(b.name)
# Out:
# UIU
# UIU
# United International University
# United International University

# %%
from copy import copy, deepcopy
class Student:
   def __init__(self, name, courses):
       self.name = name
       self.courses = courses

# DEEP COPY FUNCTION
def copy_student(obj):
   lst = []
   for c in obj.courses:
       lst.append(c)
   return Student(obj.name, lst)

#shallow copy function
def copy_new_student(obj):
    return obj


kt = Student("Kotha", ["OOP", "OOP lab"])
kt_us = copy_student(kt) #deep copy
kt_py = copy(kt) #shallow copy
kt_deep = deepcopy(kt) #deep copy
kt_new = copy_new_student(kt)
kt.courses.append("ENG")


print(kt.courses)
print(kt_us.courses)
print(kt_py.courses)
print(kt_deep.courses)
print(kt_new.courses)
# Out:
# ['OOP', 'OOP lab', 'ENG']
# ['OOP', 'OOP lab']
# ['OOP', 'OOP lab', 'ENG']
# ['OOP', 'OOP lab']
# ['OOP', 'OOP lab', 'ENG']

# %%
from copy import copy, deepcopy
class Room:
   def __init__(self, id):
       self.id = id
       self.next = None
a = Room(427)
b = Room(419)
c = Room(405)
a.next = b
b.next = c


def print_list(r):
   if r is None:
       return
   else:
       print(r.id)
       print_list(r.next)

print_list(a)
print("doing shallow copy....................")

a_copy_s = copy(a) #shallow copy
a_copy_s.id = 4027

a_copy_s.next.id = 4019


print_list(a_copy_s)
print("after shallow copy....................")
print_list(a)
print("after deep copy....................")

a_copy_d = deepcopy(a)
a_copy_d.next.id = 4019

print_list(a)

print(" doing deep copy....................")
print_list(a_copy_d)
# Out:
# 427
# 419
# 405
# doing shallow copy....................
# 4027
# 4019
# 405
# after shallow copy....................
# 427
# 4019
# 405
# after deep copy....................
# 427
# 4019
# 405
#  doing deep copy....................
# 427
# 4019
# 405

# %%
import copy
class Person :
    def __init__ (self , name ):
        self . name = name
        print ("I am the constructor of ",self . name )
    def __str__ ( self ):
        return f"I am { self . name }"
    def copyobj ( self ):
        return Person ( self . name )
print("This print is for P1")
P1 = Person(" Adib ")
P2 = copy.deepcopy ( P1 ) #deep copy
P3 = P1 #shallow copy
print("This print is for P4 or custom copy")
P4 = P3.copyobj() # custom copy method
P3.name = " Zara "
print( P1 )
print(P2 )
print( P3 )
print( P4 )
# Out:
# This print is for P1
# I am the constructor of   Adib
# This print is for P4 or custom copy
# I am the constructor of   Adib
# I am  Zara
# I am  Adib
# I am  Zara
# I am  Adib

# %%
class A:
    def __init__(self,x=0):
        self.__x=x
class B(A):
    def __init__(self,x):
        super().__init__(x)
    def change(self,n):
        self._A__x=n
b = B(15)
b.change(25)
print(b._A__x)
# Out:
# 25

# %%
class Age:
    def __init__(self,y=0,m=0):
        self.year=y
        self.month=m
    def __repr__(self): 
        return f"{self.year} years {self.month}"
a1 = Age(12,3)
a2 = Age(5,3)
a3 = Age(40,3)
listAges =[]
listAges.append(a1)
listAges.append(a2)
listAges.append(a3)
print(listAges)
# listAges.remove(Age(12,3)) # this will not work as expected because it is a different object
listAges.remove(a1)
print(listAges)
# Out:
# [12 years 3, 5 years 3, 40 years 3]
# [5 years 3, 40 years 3]

# %%
a1 = Age(12, 3)
a2 = Age(12, 3)
print(a1 == a2)  # False! (compares memory addresses)
# Out:
# False

# %%
class Age:
    def __init__(self,y=0,m=0):
        self.year=y
        self.month=m
    def __repr__(self):
        return f"{self.year} years {self.month}"
    def __eq__(self,other):
        return self.year==other.year and self.month==other.month
a1 = Age(12,3)
a2 = Age(5,3)
a3 = Age(40,3)
listAges =[]
listAges.append(a1)
listAges.append(a2)
listAges.append(a3)
print(listAges)
listAges.remove(Age(12,3))
print(listAges)
# Out:
# [12 years 3, 5 years 3, 40 years 3]
# [5 years 3, 40 years 3]

# %%
a1 = Age(12, 3)
a2 = Age(12, 3)
print(a1 == a2)  # True! (compares year and month)
# Out:
# True

# %%
class Rectangle:
    def __init__(self,w,h):
        self.w=w
        self.h=h
    def area(self):
        return self.h*self.w
    def __gt__(self,other):
        return self.area() > other.area()
    def __repr__(self):
        return f"width:{self.w} height:{self.h}"
myList = [Rectangle(4,3),Rectangle(12,3),Rectangle(40,3)]
print(max(myList))
# Out:
# width:40 height:3
